# %% [markdown]
# Ось **розгорнутий контент  першого файлу `01_basics.ipynb`** з орієнтацією на **інформаційно-аналітичну діяльність військових штабів**:
#
# ---
#
# # 📘 `01_basics.ipynb`
#
# ## **Тема: Основи Python у військовій аналітиці**
#
# ---
#
# ### 🔹 Вступ
#
# Мета заняття — ознайомитися з базовими конструкціями Python, які стануть фундаментом для подальшої обробки бойових звітів, статистики втрат, даних розвідки та інших джерел інформації.
#
# ---
#
# ### 🔸 1. Змінні та типи даних
#
# #### ▶️ Основні типи:
#
# * `int` — цілі числа (кількість втрат)
# * `float` — числа з
# плаваючою комою (відсотки готовності)
# * `str` — текст (назви підрозділів)
# * `bool` — логічні значення (готовність: True/False)
#
# #### ✅ Приклад:
#
# ```python
# enemy_losses = 120
# readiness = 0.85
# unit_name = "1-а механізована бригада"
# is_ready = True
# ```
#
# ---
#
# ### 🔸 2. Вивід інформації
#
# ```python
# print(f"{unit_name} має рівень готовності {readiness * 100}%")
# print("Втрати противника:", enemy_losses)
# ```
#
# ---
#
# ### 🔸 3. Арифметичні оператори
#
# * `+`, `-`, `*`, `/`, `//`, `%`, `**`
#
# #### ✅ Приклад:
#
# ```python
# planned = 250
# actual = 187
# shortfall = planned - actual
# print("Недокомплект:", shortfall)
# ```
#
# ---
#
# ### 🔸 4. Логічні оператори
#
# * `==`, `!=`, `<`, `>`, `<=`, `>=`
# * `and`, `or`, `not`
#
# #### ✅ Приклад:
#
# ```python
# if readiness > 0.9 and enemy_losses > 100:
#     print("Можна перейти до активних дій.")
# else:
#     print("Потрібна додаткова підготовка.")
# ```
#
# ---
#
# ### 🔸 5. Введення даних з клавіатури
#
# ```python
# direction = input("Введіть напрямок атаки: ")
# print(f"Обрано напрямок: {direction}")
# ```
#
# ---
#
# ### 🔸 6. Умовні конструкції `if`, `elif`, `else`
#
# #### ✅ Приклад:
#
# ```python
# if enemy_losses > 200:
#     print("Ворог зазнав значних втрат")
# elif enemy_losses > 100:
#     print("Втрати середні")
# else:
#     print("Втрати незначні")
# ```
#
# ---
#
# ### 🔸 7. Цикл `for` + `range()`
#
# ```python
# for day in range(1, 6):
#     print(f"День {day}: Аналіз втрат")
# ```
#
# ---
#
# ### 🔸 8. Цикл `while`
#
# ```python
# ready = 0.5
# while ready < 0.9:
#     print(f"Поточна готовність: {ready}")
#     ready += 0.1
# ```
#
# ---
#
# ### 📝 Практичні завдання:
#
# 1. Вивести повідомлення про рівень втрат противника на основі введеного числа.
# 2. Порахувати середній рівень готовності трьох підрозділів.
# 3. Створити цикл, що виводить день і номер сектора з номером розрахунку.

# %%
# 1. Вивести повідомлення про рівень втрат противника на основі введеного числа.

# Запитуємо у користувача ввести число втрат
losses = int(input("Введіть рівень втрат противника (число): "))

# Перевіряємо значення і виводимо відповідне повідомлення
if losses == 0:
    print("Втрат немає.")
elif 1 <= losses <= 10:
    print("Мінімальні втрати.")
elif 11 <= losses <= 50:
    print("Середні втрати.")
else:
    print("Великі втрати.")

# --------------------------------------------------------------

# 2. Порахувати середній рівень готовності трьох підрозділів.

# Запитуємо у користувача ввести рівень готовності для кожного підрозділу
unit1 = float(input("Введіть рівень готовності першого підрозділу (0-100): "))
unit2 = float(input("Введіть рівень готовності другого підрозділу (0-100): "))
unit3 = float(input("Введіть рівень готовності третього підрозділу (0-100): "))

# Обчислюємо середнє арифметичне
average_readiness = (unit1 + unit2 + unit3) / 3

# Виводимо результат з округленням до двох знаків після коми
print(f"Середній рівень готовності трьох підрозділів: {average_readiness:.2f}")

# --------------------------------------------------------------

# 3. Створити цикл, що виводить день і номер сектора з номером розрахунку.

# Припустимо, що у нас є 5 днів і 3 сектори.
days = 5
sectors = 3

# Зовнішній цикл - по днях
for day in range(1, days + 1):
    # Внутрішній цикл - по секторах
    for sector in range(1, sectors + 1):
        # Обчислюємо номер розрахунку (можна просто лічити порядковий номер)
        calc_number = (day - 1) * sectors + sector
        # Виводимо інформацію
        print(f"День {day}, сектор {sector}, номер розрахунку: {calc_number}")
# Out:
# Середні втрати.
# Середній рівень готовності трьох підрозділів: 58.67
# День 1, сектор 1, номер розрахунку: 1
# День 1, сектор 2, номер розрахунку: 2
# День 1, сектор 3, номер розрахунку: 3
# День 2, сектор 1, номер розрахунку: 4
# День 2, сектор 2, номер розрахунку: 5
# День 2, сектор 3, номер розрахунку: 6
# День 3, сектор 1, номер розрахунку: 7
# День 3, сектор 2, номер розрахунку: 8
# День 3, сектор 3, номер розрахунку: 9
# День 4, сектор 1, номер розрахунку: 10
# День 4, сектор 2, номер розрахунку: 11
# День 4, сектор 3, номер розрахунку: 12
# День 5, сектор 1, номер розрахунку: 13
# День 5, сектор 2, номер розрахунку: 14
# День 5, сектор 3, номер розрахунку: 15

# %% [markdown]
# ### Завдання 1. Середній рівень готовності трьох підрозділів. Gpt

# %%
losses = int(input("Введіть рівень втрат противника (число): "))
if losses == 0:
    print("Втрат немає.")
elif 1 <= losses <= 10:
    print("Мінімальні втрати.")
elif 11 <= losses <= 50:
    print("Середні втрати.")
else:
    print("Великі втрати.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 losses = int(input("Введіть рівень втрат противника (число): "))
#       2 if losses == 0:
#       3     print("Втрат немає.")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### Завдання 2. Рівень втрат противника на основі введеного числа. Gpt

# %%
unit1 = float(input("Введіть рівень готовності першого підрозділу (0-100): "))
unit2 = float(input("Введіть рівень готовності другого підрозділу (0-100): "))
unit3 = float(input("Введіть рівень готовності третього підрозділу (0-100): "))
average_readiness = (unit1 + unit2 + unit3) / 3
print(f"Середній рівень готовності трьох підрозділів: {average_readiness:.2f}")
# Out:
# Середній рівень готовності трьох підрозділів: 67.67

# %% [markdown]
# ### Завдання 3. Цикл, що виводить день і номер сектора з номером розрахунку. Gpt

# %%
days = 8
sectors = 9
for day in range(1, days + 1):
    for sector in range(1, sectors + 1):
        calc_number = (day - 1) * sectors + sector
        print(f"День {day}, сектор {sector}, номер розрахунку: {calc_number}")
# Out:
# День 1, сектор 1, номер розрахунку: 1
# День 1, сектор 2, номер розрахунку: 2
# День 1, сектор 3, номер розрахунку: 3
# День 1, сектор 4, номер розрахунку: 4
# День 1, сектор 5, номер розрахунку: 5
# День 1, сектор 6, номер розрахунку: 6
# День 1, сектор 7, номер розрахунку: 7
# День 1, сектор 8, номер розрахунку: 8
# День 1, сектор 9, номер розрахунку: 9
# День 2, сектор 1, номер розрахунку: 10
# День 2, сектор 2, номер розрахунку: 11
# День 2, сектор 3, номер розрахунку: 12
# День 2, сектор 4, номер розрахунку: 13
# День 2, сектор 5, номер розрахунку: 14
# День 2, сектор 6, номер розрахунку: 15
# День 2, сектор 7, номер розрахунку: 16
# День 2, сектор 8, номер розрахунку: 17
# День 2, сектор 9, номер розрахунку: 18
# День 3, сектор 1, номер розрахунку: 19
# День 3, сектор 2, номер розрахунку: 20
# День 3, сектор 3, номер розрахунку: 21
# День 3, сектор 4, номер розрахунку: 22
# День 3, сектор 5, номер розрахунку: 23
# День 3, сектор 6, номер розрахунку: 24
# ...

# %% [markdown]
# ### Завдання 1. Середній рівень готовності трьох підрозділів.

# %%
Losses = int(input("Введіть рівень втрат противника(чмсло):"))
if Losses == 0:
    print("Втрати не значні")
elif 1<= Losses <= 20:
    print("Середні втрати")
elif 20<= Losses <= 70:
    print("Великі втрати")
else:
    print("Колосальні втрати")
# Out:
# Колосальні втрати
